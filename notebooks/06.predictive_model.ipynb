# %% [markdown]
# # Import Modules

# %%
import importlib
import os
import sys

import joblib
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
os.chdir("../")
sys.path.insert(0, os.getcwd())

# %%
from morai.experience import charters, experience
from morai.forecast import metrics, preprocessors
from morai.models import base, gam
from morai.utils import custom_logger, helpers

# %%
logger = custom_logger.setup_logging(__name__)

# %%
# update log level if wanting more logging
custom_logger.set_log_level("INFO")

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
# default is "plotly_mimetype+notebook", however that takes up space.
# "plotly_mimetype+notebook_connected" seems to save space
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"

# %% [markdown]
# # Data

# %%
pl_parquet_path = r"files/dataset/mortality_grouped.parquet"

# %%
# reading in the dataset
# `enable_string_cache` helps with categorical type values
pl.enable_string_cache()
lzdf = pl.scan_parquet(
    pl_parquet_path,
)

# %%
initial_row_count = lzdf.select(pl.len()).collect().item()
print(
    f"row count: {initial_row_count:,} \n"
    f"exposures: {lzdf.select([pl.col('amount_exposed').sum()]).collect()[0,0]:,}"
)
# Out:
# row count: 1,793,371
# exposures: 9,824,025,879,572.559

# %%
grouped_df = lzdf.collect()

# %%
grouped_df = grouped_df.to_pandas()

# %% [markdown]
# # Preparing Data

# %% [markdown]
# ## Filter

# %%
model_data = grouped_df[
    (grouped_df["attained_age"] >= 50)
    # & (grouped_df["attained_age"] <= 95)
    & (grouped_df["issue_age"] >= 30)
    & (grouped_df["issue_age"] <= 80)
].copy()
model_data = model_data.reset_index(drop=True)

# %%
del grouped_df

# %% [markdown]
# ## Calculated Fields

# %%
model_data["capped_duration"] = model_data["duration"].clip(upper=26)
model_data["qx_log_raw"] = np.log(model_data["qx_raw"] + 1)
binned_face_dict = {
    "01: 0 - 9,999": "01: 0 - 24,999",
    "02: 10,000 - 24,999": "01: 0 - 24,999",
    "03: 25,000 - 49,999": "02: 25,000 - 99,999",
    "04: 50,000 - 99,999": "02: 25,000 - 99,999",
    "05: 100,000 - 249,999": "03: 100,000 - 249,999",
    "06: 250,000 - 499,999": "04: 250,000 - 4,999,999",
    "07: 500,000 - 999,999": "04: 250,000 - 4,999,999",
    "08: 1,000,000 - 2,499,999": "04: 250,000 - 4,999,999",
    "09: 2,500,000 - 4,999,999": "04: 250,000 - 4,999,999",
    "10: 5,000,000 - 9,999,999": "05: 5,000,000+",
    "11: 10,000,000+": "05: 5,000,000+",
}
model_data["binned_face"] = model_data["face_amount_band"].map(binned_face_dict)
model_data["binned_face"] = model_data["binned_face"].astype("category")

# %% [markdown]
# ## Feature Dictionary

# %%
feature_dict = {
    "target": ["qx_raw"],
    "weight": ["amount_exposed"],
    "passthrough": ["attained_age", "duration", "observation_year"],
    "ordinal": [
        "sex",
        "smoker_status",
    ],
    "ohe": [
        "binned_face",
        "insurance_plan",
        "class_enh",
    ],
    "nominal": [],
}

feature_dict_vbt = {
    "target": ["qx_raw"],
    "weight": ["amount_exposed"],
    "passthrough": ["attained_age", "capped_duration"],
    "ordinal": [
        "sex",
        "smoker_status",
    ],
    "ohe": [],
    "nominal": [],
}

# %% [markdown]
# ## Model Results Dictionary

# %%
metric_cols = ["ae", "smape", "r2_score", "root_mean_squared_error", "aic", "shape"]
model_results = metrics.ModelResults(metrics=metric_cols)

# %% [markdown]
# ### VBT15

# %%
model_name = "vbt15"

# %%
scorecard = model_results.get_scorecard(
    y_true_train=model_data["death_claim_amount"],
    y_pred_train=model_data[f"exp_amt_{model_name}"],
    weights_train=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=None,
    model_params=None,
    scorecard=scorecard,
    importance=None,
)
# Out:
#  2025-05-12 23:08:03 | morai.forecast.metrics | INFO     | Adding model 'vbt15'

# %% [markdown]
# # Forecasting Models

# %%
# # build
model_build = True
model_load = False
model_save = True

# %%
# load
model_build = False
model_load = True
model_save = False

# %% [markdown]
# ## GLM

# %% [markdown]
# **Overview:**
# - GLM is a flexible generalization of ordinary linear regression models. It supports non-normal distributions of the dependent variable.
#
# **Feature Preprocessing:**
#   - GLM - using one-hot enconding (ohe) as the model needs the categories to be diferentiated and not ordinal or nominal. This only applies to non-binary features.
#   - Scaling should be considered to ensure the features aren't overly weighted by larger values.
#
# **Model Characteristics**
#   - GLM is a simpler type of model and is easily understandable. May struggle with complex, non-linear interactions without suitable transformations or feature engineering.

# %%
model_name = "glm"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    add_constant=True,
)
# Out:
#  2025-05-13 00:04:08 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-13 00:04:08 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-13 00:04:08 | morai.forecast.preprocessors | INFO     | adding a constant column to the data
#  2025-05-13 00:04:08 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration', 'constant']
#  2025-05-13 00:04:08 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status']
#  2025-05-13 00:04:09 | morai.forecast.preprocessors | INFO     | nominal - one hot encoded (dropping first col): ['binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
GLM = base.GLM()
if model_build:
    GLM.fit(X=X_train, y=y_train, weights=weights_train, r_style=False)
if model_load:
    GLM.model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(GLM.model)}")
    GLM.is_fitted_ = True
if model_save:
    joblib.dump(GLM.model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(GLM.model)}")

model_params = {"weights": True, "r_style": False}
model_params.update({"family": GLM.model.family})
# Out:
#  2025-05-13 00:04:11 | morai.models.base | INFO     | fiting the model
#  2025-05-13 00:04:11 | morai.models.base | INFO     | setup GLM model with statsmodels and <statsmodels.genmod.families.family.Binomial object at 0x000001C30F542420> family...
#  2025-05-13 00:04:30 | __main__ | INFO     | saved model 'glm'. type: <class 'statsmodels.genmod.generalized_linear_model.GLMResultsWrapper'>

# %%
print(GLM.model.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 qx_raw   No. Observations:               877381
# Model:                            GLM   Df Residuals:         3418917283149.29
# Model Family:                Binomial   Df Model:                           24
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -7.5391e+10
# Date:                Tue, 13 May 2025   Deviance:                   7.4554e+10
# Time:                        00:04:31   Pearson chi2:                 5.27e+11
# No. Iterations:                    10   Pseudo R-squ. (CS):              1.000
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# attained_age                            0.1175    8.7e-07   1.35e+05      0.000       0.117       0.118
# binned_face_02: 25,000 - 99,999        -0.1364   5.29e-05  -2580.501      0.000      -0.137      -0.136
# binned_face_03: 100,000 - 249,999      -0.2223   5.21e-05  -4263.402      0.000      -0.222      -0.222
# binned_face_04: 250,000 - 4,999,999    -0.2696   5.12e-05  -5266.585      0.000      -0.270      -0.270
# binned_face_05: 5,000,000+             -0.4396   5.61e-05  -7837.071      0.000      -0.440      -0.439
# class_enh_2_2                           0.3486    3.4e-05   1.03e+04      0.000       0.349       0.349
# class_enh_3_1                          -0.1304   4.27e-05  -3049.303      0.000      -0.130      -0.130
# class_enh_3_2                          -0.1331    3.9e-05  -3410.334      0.000      -0.133      -0.133
# class_enh_3_3                           0.2051   3.51e-05   5839.755      0.000       0.205       0.205
# class_enh_4_1                          -0.3589   4.63e-05  -7753.404      0.000      -0.359      -0.359
# class_enh_4_2                          -0.1538    4.8e-05  -3204.208      0.000      -0.154      -0.154
# class_enh_4_3                           0.1427   5.24e-05   2721.311      0.000       0.143       0.143
# class_enh_4_4                           0.1807   5.25e-05   3445.059      0.000       0.181       0.181
# class_enh_NA_NA                         0.0622   3.06e-05   2037.035      0.000       0.062       0.062
# class_enh_U_U                           0.0600   7.17e-05    836.986      0.000       0.060       0.060
# constant                               -2.0198      0.008   -267.598      0.000      -2.035      -2.005
# duration                                0.0250   1.46e-06   1.71e+04      0.000       0.025       0.025
# insurance_plan_Term                     0.1344   3.12e-05   4305.612      0.000       0.134       0.135
# insurance_plan_UL                       0.2549   2.55e-05   9979.523      0.000       0.255       0.255
# insurance_plan_ULSG                     0.0394   3.25e-05   1213.471      0.000       0.039       0.039
# insurance_plan_VL                       0.1657   4.06e-05   4078.799      0.000       0.166       0.166
# insurance_plan_VLSG                     0.2414   5.26e-05   4585.609      0.000       0.241       0.242
# observation_year                       -0.0057   3.75e-06  -1517.392      0.000      -0.006      -0.006
# sex                                     0.2930   1.78e-05   1.65e+04      0.000       0.293       0.293
# smoker_status                           0.8697   2.86e-05   3.04e+04      0.000       0.870       0.870
# =======================================================================================================

# %%
predictions = GLM.predict(X)
print(f"NA values: {np.isnan(predictions).sum()}")
# Out:
# NA values: 0

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
odds = GLM.get_odds(display=False)
importance = base.ModelWrapper(GLM.model).get_importance()
# Out:
#  2025-05-13 00:04:32 | morai.models.base | INFO     | generating odds ratio from model

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=GLM.model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=GLM.model.predict(X_test),
    weights_test=weights_test,
    model=GLM.model,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-13 00:04:32 | morai.forecast.metrics | INFO     | Adding model 'glm'

# %%
charters.compare_rates(
    df=model_data[model_data["insurance_plan"].isin(["UL", "ULSG"])],
    x_axis="duration",
    rates=["ae_glm", "ae_vbt15"],
    weights=["exp_amt_glm", "exp_amt_vbt15"],
    secondary="death_count",
    x_bins=6,
    display=True,
)
# Out:
#  2025-05-13 00:04:33 | morai.experience.charters | INFO     | Binning feature: [duration] with 6 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ca651392-e83e-4193-981e-8a31565aa520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ca651392-e83e-4193-981e-8a31565aa520")) {                    Plotly.newPlot(                        "ca651392-e83e-4193-981e-8a31565aa520",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death
AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["01: 0 - 24,999","02: 25,000 - 99,999","03: 100,000 - 249,999","04: 250,000 - 4,999,999","05: 5,000,000+"],"y":{"dtype":"f8","bdata":"ZAEAAAAA8D9vAQAAAADwP3sBAAAAAPA\u002ffwEAAAAA8D9zAQAAAADwPw=="},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["2_1","2_2","3_1","3_2","3_3","4_1","4_2","4_3","4_4","NA_NA","U_U"],"y":{"dtype":"f8","bdata":"bQEAAAAA8D90AQAAAADwP4MBAAAAAPA\u002fgwEAAAAA8D94AQAAAADwP3oBAAAAAPA\u002ffQEAAAAA8D96AQAAAADwP4oBAAAAAPA\u002fewEAAAAA8D+BAQAAAADwPw=="},"type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i1","bdata":"AQ=="},"y":{"dtype":"f8","bdata":"egEAAAAA8D8="},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i4","bdata":"AQAAAAIAAAADAAAABAAAAAUAAAAGAAAABwAAAAgAAAAJAAAACgAAAAsAAAAMAAAADQAAAA4AAAAPAAAAEAAAABEAAAASAAAAEwAAABQAAAAVAAAAFgAAABcAAAAYAAAAGQAAABoAAAAbAAAAHAAAAB0AAAAeAAAAHwAAACAAAAAhAAAAIgAAACMAAAAkAAAAJQAAACYAAAAnAAAA"},"y":{"dtype":"f8","bdata":"d\u002f3PewH32D+3AcaCKs\u002fmP2IMkSqSYuo\u002f74vuenmf6j8krTXuz5\u002fuP8Iq2LQvMfA\u002fSihcwhqP7j9HxlN1G5buP\u002fTxSltZt\u002fE\u002fNdDBEXzT8j9zVSL8xHXwP0xNYs08ivA\u002fT5FEtqiB8D+2Bz6zOerwP2IlxnQxnPE\u002fwTbjfxL28D9\u002fOFrPA5\u002fxP4YIXZ7TGfA\u002fc0p68oXz8D+C4\u002fUTkz7xP+XxEP+TvvE\u002fWaFKh83c8D+\u002fyN\u002fWzX7xP\u002fRWH5gxyPA\u002fQZ\u002fpq+Gz8D\u002f8f90t4T7uP8M3sKhqi+8\u002ffGEi9JJ\u002f7j9ccjKrLr7vPxO2eIdR6es\u002f9nuOIW0D7j+Tt+gwqKPrP8jYPTe40Ow\u002f9TTkrcfO6T8QEDFuDiXrP+FGxRPQb+o\u002f7KZXuxP15z8JC\u002fMdYf7uPzrViFLXNfI\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"eAEAAAAA8D92AQAAAADwP3kBAAAAAPA\u002fhAEAAAAA8D95AQAAAADwP3oBAAAAAPA\u002f"},"type":"scatte ...

# %% [markdown]
# ## GAM

# %% [markdown]
# **Overview:**
# - Generalized Additive Models (GAMs) are a class of regression models that combine the interpretability of linear models with the flexibility of non-linear models by fitting separate smooth functions to each feature.
#
# **Feature Preprocessing:**
#   - GAMs can handle both numeric and categorical features, but numeric features may require scaling or transformation for optimal results.
#
# **Model Characteristics**
#   - GAMs handle non-linear relationships effectively through smooth functions while maintaining interpretability.
#   - Unlike tree-based models, GAMs do not split data but instead apply smooth functions to individual predictors.

# %%
model_name = "gam"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    add_constant=True,
)
# Out:
#  2025-05-12 23:18:08 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-12 23:18:08 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-12 23:18:08 | morai.forecast.preprocessors | INFO     | adding a constant column to the data
#  2025-05-12 23:18:08 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration', 'constant']
#  2025-05-12 23:18:08 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status']
#  2025-05-12 23:18:09 | morai.forecast.preprocessors | INFO     | nominal - one hot encoded (dropping first col): ['binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
GAM = gam.GAMR()
spline_dict = {
    "attained_age": {"df":12, "degree": 3, "bs":"ps"},
}
if model_build:
    GAM.setup_model(
        X=X_train, y=y_train, weights=weights_train, spline_dict=spline_dict
    )
if model_load:
    GAM.model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(GAM.model)}")
    GAM.is_fitted_ = True
if model_save:
    joblib.dump(GAM.model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(GAM.model)}")

model_params = {"weights": True}
model_params.update({"family": GAM.family})
model_params.update({"splne_dict": spline_dict})
# Out:
#  2025-05-12 23:18:11 | morai.models.gam | INFO     | setup GAM model with mgcv and `quasibinomial` distribution with `logit` link
#  2025-05-12 23:18:17 | morai.models.gam | INFO     | formula:
#  2025-05-12 23:18:17 | morai.models.gam | INFO     | > qx_raw ~ s(`attained_age`, k=12, m=3, bs='ps')+`binned_face_02__25_000___99_999`+`binned_face_03__100_000___249_999`+`binned_face_04__250_000___4_999_999`+`binned_face_05__5_000_000plus`+`class_enh_2_2`+`class_enh_3_1`+`class_enh_3_2`+`class_enh_3_3`+`class_enh_4_1`+`class_enh_4_2`+`class_enh_4_3`+`class_enh_4_4`+`class_enh_NA_NA`+`class_enh_U_U`+`constant`+`duration`+`insurance_plan_Term`+`insurance_plan_UL`+`insurance_plan_ULSG`+`insurance_plan_VL`+`insurance_plan_VLSG`+`observation_year`+`sex`+`smoker_status`
#  2025-05-12 23:21:36 | morai.models.gam | INFO     | fitting the model:
#  2025-05-12 23:21:36 | morai.models.gam | INFO     | > model <- bam(formula, data=data, weights=weights, family=family, drop.intercept=TRUE)`
#  2025-05-12 23:23:11 | morai.models.gam | INFO     | model fitted
#  2025-05-12 23:23:13 | __main__ | INFO     | saved model 'gam'. type: <class 'rpy2.robjects.vectors.ListVector'>

# %%
print(GAM.summary(expand=True))
# Out:
# Generalized Additive Model (mgcv) Summary
# ======================================================================
# Family                : quasibinomial
# Link                  : logit
# Number of Observations: 877381
# Adjusted R-squared    : 0.104
# Deviance Explained    : 32.5%
# Scale Estimate        : 5.751e+05
# fREML                 : 7.063e+06
#
# Formula:
# qx_raw ~ s(`attained_age`, k=12, m=3, bs='ps')+`binned_face_02__25_000___99_999`+`binned_face_03__100_000___249_999`+`binned_face_04__250_000___4_999_999`+`binned_face_05__5_000_000plus`+`class_enh_2_2`+`class_enh_3_1`+`class_enh_3_2`+`class_enh_3_3`+`class_enh_4_1`+`class_enh_4_2`+`class_enh_4_3`+`class_enh_4_4`+`class_enh_NA_NA`+`class_enh_U_U`+`constant`+`duration`+`insurance_plan_Term`+`insurance_plan_UL`+`insurance_plan_ULSG`+`insurance_plan_VL`+`insurance_plan_VLSG`+`observation_year`+`sex`+`smoker_status`
#
# Parametric Coefficients:
# binned_face_02__25_000___99_999       -0.11
# binned_face_03__100_000___249_999     -0.21
# binned_face_04__250_000___4_999_999   -0.30
# binned_face_05__5_000_000plus         -0.50
# class_enh_2_2                          0.35
# class_enh_3_1                         -0.11
# class_enh_3_2                         -0.11
# class_enh_3_3                          0.23
# class_enh_4_1                         -0.34
# class_enh_4_2                         -0.11
# class_enh_4_3                          0.18
# class_enh_4_4                          0.23
# class_enh_NA_NA                        0.07
# class_enh_U_U                          0.08
# constant                              10.82
# duration                               0.03
# insurance_plan_Term                    0.10
# insurance_plan_UL                      0.26
# insurance_plan_ULSG                    0.06
# insurance_plan_VL                      0.18
# insurance_plan_VLSG                    0.26
# observation_year                      -0.01
# sex                                    0.33
# smoker_status                          0.89
#
# Smooth Terms:
#                  edf  Ref.df        F  p-value         alpha
# s(attained_age) 6.67    7.29 4,685.49     0.00 56,590,584.46
#
# Expanded Smooth Terms:
#                   name  coef
# 24   s(attained_age).1  0.78
# 25   s(attained_age).2  1.96
# 26   s(attained_age).3  2.95
# 27   s(attained_age).4  3.53
# 28   s(attained_age).5  4.33
# 29   s(attained_age).6  5.25
# 30   s(attained_age).7  6.32
# 31   s(attained_age).8  7.79
# 32   s(attained_age).9  8.10
# 33  s(attained_age).10  6.95
# 34  s(attained_age).11  4.25

# %%
predictions = GAM.predict(X)
# Out:
#  2025-05-12 23:27:12 | morai.models.gam | INFO     | predicted rates

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=GAM.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=GAM.predict(X_test),
    weights_test=weights_test,
    model=GAM.model,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=None,
)
# Out:
#  2025-05-12 23:30:24 | morai.models.gam | INFO     | predicted rates
#  2025-05-12 23:31:13 | morai.models.gam | INFO     | predicted rates
#  2025-05-12 23:31:13 | morai.forecast.metrics | ERROR    | Model `
# Family: quasibinomial
# Link function: logit
#
# Formula:
# qx_raw ~ s(attained_age, k = 12, m = 3, bs = "ps") + binned_face_02__25_000___99_999 +
#     binned_face_03__100_000___249_999 + binned_face_04__250_000___4_999_999 +
#     binned_face_05__5_000_000plus + class_enh_2_2 + class_enh_3_1 +
#     class_enh_3_2 + class_enh_3_3 + class_enh_4_1 + class_enh_4_2 +
#     class_enh_4_3 + class_enh_4_4 + class_enh_NA_NA + class_enh_U_U +
#     constant + duration + insurance_plan_Term + insurance_plan_UL +
#     insurance_plan_ULSG + insurance_plan_VL + insurance_plan_VLSG +
#     observation_year + sex + smoker_status
#
# Estimated degrees of freedom:
# 6.67  total = 30.67
#
# fREML score: 7063080
# ` does not have AIC attribute, returning None
#  2025-05-12 23:31:13 | morai.forecast.metrics | ERROR    | Model `
# Family: quasibinomial
# Link function: logit
#
# Formula:
# qx_raw ~ s(attained_age, k = 12, m = 3, bs = "ps") + binned_face_02__25_000___99_999 +
#     binned_face_03__100_000___249_999 + binned_face_04__250_000___4_999_999 +
#     binned_face_05__5_000_000plus + class_enh_2_2 + class_enh_3_1 +
#     class_enh_3_2 + class_enh_3_3 + class_enh_4_1 + class_enh_4_2 +
#     class_enh_4_3 + class_enh_4_4 + class_enh_NA_NA + class_enh_U_U +
#     constant + duration + insurance_plan_Term + insurance_plan_UL +
#     insurance_plan_ULSG + insurance_plan_VL + insurance_plan_VLSG +
#     observation_year + sex + smoker_status
#
# Estimated degrees of freedom:
# 6.67  total = 30.67
#
# fREML score: 7063080
# ` does not have AIC attribute, returning None
# %% [markdown]
# ## Linear Regression

# %% [markdown]
# **Feature Preprocessing:**
# - Linear regression needs all features to be numeric.

# %%
model_name = "lr"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
)
# Out:
#  2025-05-12 23:31:15 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-12 23:31:15 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-12 23:31:15 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration']
#  2025-05-12 23:31:15 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status']
#  2025-05-12 23:31:16 | morai.forecast.preprocessors | INFO     | nominal - one hot encoded (dropping first col): ['binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
from sklearn import linear_model

if model_build:
    model = linear_model.LinearRegression()
    model.fit(X_train, y_train, sample_weight=weights_train)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:31:19 | __main__ | INFO     | saved model 'lr'. type: <class 'sklearn.linear_model._base.LinearRegression'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:31:20 | morai.forecast.metrics | ERROR    | Model name lr already exists, not adding model. Please use a different name.

# %%
charters.compare_rates(
    model_data,
    x_axis="attained_age",
    rates=["qx_raw", "qx_vbt15", "qx_lr"],
    weights=["amount_exposed"],
    secondary="death_count",
)
# Out:
#  2025-05-12 23:31:20 | morai.experience.charters | INFO     | The weights list is 1 long and should be 3 long. Using the first weight for all weights.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="6255dbf0-0a01-4950-a74d-d01e4ecbab28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6255dbf0-0a01-4950-a74d-d01e4ecbab28")) {                    Plotly.newPlot(                        "6255dbf0-0a01-4950-a74d-d01e4ecbab28",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death_count","x":{"dtype":"i4","bdata":""},"y":{"dtype":"f8","bdata":"AAAAAABAjEAAAAAAAMCOQAAAAAAAVJBAAAAAAABQk0AAAAAAAKCVQAAAAAAA6JhAAAAAAAComkAAAAAAAHCdQAAAAAAAJKBAAAAAAADgoUAAAAAAAE6jQAAAAAAAAKRAAAAAAABapUAAAAAAALqnQAAAAAAAEKpAAAAAAAAgq0AAAAAAAOSqQAAAAAAA+qpAAAAAAAC8rUAAAAAAAG6uQAAAAAAA\\u002fAAAAAAAA8D8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"type":"bar","xaxis":"x","yaxis":"y2"},{"mode":"lines+markers","name":"qx_raw","x":{"dtype":"i4","bdata":""},"y":{"dtype":"f8","bdata":"7zjQLXfyTD+F9ZaisuxPPwskcbrq4VA\u002foJWJdxwJUj\u002favGNW96FYPzKip7GN71c\u002fwcXyNBOFXz9lWiNRxxJeP56kOjYytGA\u002fn2aHzuOAYz8W9UXeURFmP9VmuAc9kWQ\u002fdp8wckSsZz\u002fPVpK7hflrPy7iC5WUP3A\u002fmoRUg3qRcz8GTkna0QNzP6f1E6FkJHU\u002fJlAiTc+ReD8mRrqidqB7PxBmbTubEYA\u002fHVWnsmnUgj\u002fetMlVm8KEP9C+
o\u002fEOHRGH8z6z9ISpLl\u002f1TtP5JhX7Lbi\u002fA\u002fZ9ZI2r9r7z\u002f9mLHam2zvP0nCPlu68u0\u002fqRk4BmKy7z\u002fKQMcDn1ntP8Hfb77eJvA\u002fFVA4q1u48D\u002fEs43T+YbxP10npWXFLPA\u002ffsFGX8Mp8T8INOco6dTwPyFigtKepfI\u002frFf3YB+Q8T\u002ftzYgPH67yP8\u002fA8cR2MfI\u002fL7nDc3Aa8z8rIxLmEMj3P42UlMwG0Pk\u002f"},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"psT4QoPf7z8uvnUHX\u002fPvPw\u002fzgUVlW+8\u002fRR8heqg68D+y3UhWMF\u002fvPzddVghT7O8\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata":"YFO5RGAF7j+VjxsCG6DwP9Wj7YLkcfA\u002fDzh2PAM48D9cPQC+LEbvP7 ...

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# **Feature Preprocessing:**
#   - Tree is using ordinal as there is no categorical for this implementation of decision tree
#   - Scaling is not necessary in decision trees as the splits are done at certain points and not scaled

# %%
model_name = "tree"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    preset="tree",
)
# Out:
#  2025-05-12 23:31:22 | morai.forecast.preprocessors | INFO     | using 'tree' preset which doesn't need to use 'nominal' or 'ohe' and instead uses 'ordinal'
#  2025-05-12 23:31:22 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-12 23:31:22 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-12 23:31:22 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration']
#  2025-05-12 23:31:22 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status', 'binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
from sklearn.tree import DecisionTreeRegressor

if model_build:
    model = DecisionTreeRegressor(max_depth=6)
    model.fit(X_train, y_train, sample_weight=weights_train)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")
model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:31:28 | __main__ | INFO     | saved model 'tree'. type: <class 'sklearn.tree._classes.DecisionTreeRegressor'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:31:29 | morai.forecast.metrics | ERROR    | Model name tree already exists, not adding model. Please use a different name.

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="c0cf3e43-f528-432a-be9a-4bec2222a1ce" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c0cf3e43-f528-432a-be9a-4bec2222a1ce")) {                    Plotly.newPlot(                        "c0cf3e43-f528-432a-be9a-4bec2222a1ce",                        [{"hovertemplate":"feature=%{x}\u003cbr\u003eimportance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["attained_age","duration","binned_face","smoker_status","sex","observation_year","class_enh","insurance_plan"],"xaxis":"x","y":{"dtype":"f8","bdata":"+Bid5mgI6T+LqpVNQvCuP4XK4Poyya4\u002fm\u002fFTC8gJpT+tM7RKCQ+WP+dHsuJW1JI\u002fnICh868Fiz8mv4bsgjFoPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","mar
002foD+Ax+917z9ZvpXqFqvwPzel7FltV\u002fA\u002f0WxehhJ88D+bPjLF4azxP\u002f1stNAFC\u002fE\u002fojUcfy4u8D8g7jkL\u002fxTvPwF5S1I1svA\u002fFgf1ZnUk8D\u002fCSp8nyjTxP3SBNBrSvPA\u002fLCSwqoYu8T9frCh\u002fhq3vP8SER4\u002fC+PA\u002fC9YPYHa88D9bOvz2x6jxPw6mQh01A\u002fA\u002fIbf+DdLL8T9Vi3jw1r\u002fwP5dghWa5svE\u002f13qEmxfC7z\u002f8Wzi3VfXwP3SIVrNA2\u002fA\u002fg1olY+5f7T\u002f3HFVeTiv0P12gPb7p5vc\u002f"},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"WtnutH9F7z8\u002f+Y5wbl7uP9hPFvI8j\u002fI\u002fgbtwZZGg7D\u002f\u002fNZFfmYjxP8FxpguPmvI\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8 ...

# %% [markdown]
# ## Random Forest

# %% [markdown]
# **Feature Preprocessing:**
#   - Tree is using ordinal as there is no categorical for this implementation of decision tree
#   - Scaling is not necessary in decision trees as the splits are done at certain points and not scaled
#
# **Model Characteristics**
#   - Random Forest is good at finding non-linear relationships and is a `bagging` type model which limits overfitting.

# %%
model_name = "rf"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    preset="tree",
)
# Out:
#  2025-05-12 23:31:32 | morai.forecast.preprocessors | INFO     | using 'tree' preset which doesn't need to use 'nominal' or 'ohe' and instead uses 'ordinal'
#  2025-05-12 23:31:32 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-12 23:31:32 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-12 23:31:32 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration']
#  2025-05-12 23:31:32 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status', 'binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
from sklearn.ensemble import RandomForestRegressor

if model_build:
    model = RandomForestRegressor(
        n_estimators=100,
        max_depth=15,
        min_samples_split=5,
        min_samples_leaf=5,
        oob_score=True,
        random_state=42,
    )

    model.fit(X_train, y_train, sample_weight=weights_train)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:38:27 | __main__ | INFO     | saved model 'rf'. type: <class 'sklearn.ensemble._forest.RandomForestRegressor'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:39:37 | morai.forecast.metrics | ERROR    | Model name rf already exists, not adding model. Please use a different name.

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="ede8c4d7-df86-4605-9080-f3296518fa21" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ede8c4d7-df86-4605-9080-f3296518fa21")) {                    Plotly.newPlot(                        "ede8c4d7-df86-4605-9080-f3296518fa21",                        [{"hovertemplate":"feature=%{x}\u003cbr\u003eimportance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["attained_age","duration","observation_year","class_enh","insurance_plan","binned_face","sex","smoker_status"],"xaxis":"x","y":{"dtype":"f8","bdata":"uN8v8fnz1D83rPYWk9\u002fIP1fk6wGoDcM\u002fgU9q7cvHvz+QGKKcSh20PyTc7wyVGrM\u002feOkFTwlgoz+DOOFXji+NPw=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker ...

# %%
charters.compare_rates(
    df=model_data[model_data["insurance_plan"].isin(["UL", "ULSG"])],
    x_axis="duration",
    rates=["ae_rf", "ae_vbt15"],
    weights=["exp_amt_rf", "exp_amt_vbt15"],
    secondary="death_count",
    x_bins=6,
    display=True,
)
# Out:
#  2025-05-12 23:39:38 | morai.experience.charters | INFO     | Binning feature: [duration] with 6 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="945b249b-f673-4c33-8e3e-439afff32206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("945b249b-f673-4c33-8e3e-439afff32206")) {                    Plotly.newPlot(                        "945b249b-f673-4c33-8e3e-439afff32206",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death_count","x":["1-6","14-19","20-26","27-32","33-39","7-13"],"y":{"dtype":"f8","bdata":"AAAAAADSpUAAAAAAALy8QAAAAAAAwMtAAAAAAAAUzUAAAAAAAD6rQAAAAAAAqrtA"},"type":"bar","xaxis":"x","yaxis":"y2"},{"mode":"lines+markers","name":"ae_rf","x":["1-6","14-19","20-26","27-32","33-39","7-13"],"y":{"dtype":"f8","bdata":"HHHBdaB77j\u002fpWvHhEdLwP+uBC5rrIvA\u002fR8gpVIWY8D\u002fs0MYmXIzvP1hhGyH8ePA\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"ae_vbt15","x":["1-6","14-19","20-26","27-32","33-39","7-13"],"y":{"dtype":"f8","bdata":"ashSqRAd6j\u002f6YgFeRBPtP8pSTZprBfI\u002fV99cERfU8z\u002f7lDIiG8bzP1L9rtaJcek\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[ ...

# %%
charters.target(
    df=model_data,
    target="ratio",
    cols=3,
    features=model_features + ["duration", "issue_year"],
    numerator=["death_claim_amount"],
    denominator=["exp_amt_rf"],
).show()
# Out:
#  2025-05-12 23:39:38 | morai.experience.charters | INFO     | Creating '11' target plots.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="60ff61b8-d500-4359-9882-e0f1bd4dac1e" class="plotly-graph-div" style="height:1600px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("60ff61b8-d500-4359-9882-e0f1bd4dac1e")) {                    Plotly.newPlot(                        "60ff61b8-d500-4359-9882-e0f1bd4dac1e",                        [{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":true,"x":{"dtype":"i4","bdata":""},"y":{"dtype":"f8","bdata":"7jTrxtpl7j++EQYFpvDvP4VZDABuP\u002fA\u002fxBXY8UcU7z95CvVf\u002fxbxP8\u002f8wZ9WW+8\u002fIfM5alrH7j\u002fwt9wJchnwP6bTlOHRCPA\u002fMFxzWRhx7j9Nd1VCw2XwP1s3JlqrBe8\u002fn3BUDK+O7z8d9cebq4jvP3t57\u002fNhJe4\u002fNubavTCI7z85P3iSGpXvP3TfBmyvM+8\u002f5DZObl017z8Pol3+Q+jvP\u002fDkiw5x5u8\u002f1tncDBzB7z8epSHDvzLwP+vE7nrkUu8\u002fTfdjCxG+7z+5+ICAwbjuPwWSnbGPFPA\u002fFd5rK5i18T\u002fFO3MyKfHvPxjmyvJtW+4\u002fASOEHK1A7j+TMVVex3HwP4PtKweiH+8\u002f8KRAO9RE7j\u002fOwu4Ga0zvP9TBxF1Gx\u002fA\u002ftJ1KooIl8D8MB8tozMfvP+l6vg7zR\u002fA\u002fFy\u002fjhEmX8D\u002fO6AsXqXDvP
| morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration']
#  2025-05-12 23:39:39 | morai.forecast.preprocessors | INFO     | ordinal - ordinal encoded: ['sex', 'smoker_status']
#  2025-05-12 23:39:40 | morai.forecast.preprocessors | INFO     | nominal - one hot encoded (dropping first col): ['binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
from sklearn.ensemble import GradientBoostingRegressor

if model_build:
    model = GradientBoostingRegressor(
        n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42
    )
    model.fit(X_train, y_train, sample_weight=weights_train)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:43:06 | __main__ | INFO     | saved model 'gbm'. type: <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:43:14 | morai.forecast.metrics | INFO     | Adding model 'gbm'

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="e31eb671-a0cd-49cf-b6e4-a37f8a539126" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e31eb671-a0cd-49cf-b6e4-a37f8a539126")) {                    Plotly.newPlot(                        "e31eb671-a0cd-49cf-b6e4-a37f8a539126",                        [{"hovertemplate":"feature=%{x}\u003cbr\u003eimportance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["attained_age","duration","smoker_status","sex","binned_face_05: 5,000,000+","observation_year","class_enh_U_U","class_enh_2_2","insurance_plan_UL","class_enh_3_3","insurance_plan_ULSG","insurance_plan_Term","class_enh_4_2","binned_face_02: 25,000 - 99,999","class_enh_3_2","class_enh_NA_NA","class_enh_4_4","binned_face_04: 250,000 - 4,999,999","class_enh_4_1","class_enh_4_3","insurance_plan_VLSG","binned_face_03: 100,000 - 249,999","insurance_plan_VL","class_enh_3_1"],"xaxis":"x","y":{"dtype":"f8","bdata":"ugIud1bi6T8y56NqDaCxP4a8hvXbIqI\u002feLhZXfHOlz9TLGiHJJCPP8qH3\u002f2swos\u002fAL5AiQurgz8bf2uBiTd4P+WPu9VDdnI\u002f0H8Byxz7cT\u002fukwL5Kj9oP8oR7SSY0GY\u002f\u002f99Nzlk7YD\u002fpour7g\u002fZTP6xsSBJFRT0\u002fvYt3GQYIND99q8r7qHwhP3aXQ+Q9uiA\u002fEZ9fI86LHj9qavAM1f4RP9KMp8oKawg\u002fuXiKvVzo\u002fz4AAAAAAAAAAAAAAAAAAAAA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatter ...

# %%
charters.compare_rates(
    model_data,
    x_axis="attained_age",
    rates=["qx_raw", "qx_vbt15", "qx_gbm"],
    weights=["amount_exposed"],
    secondary="death_count",
)
# Out:
#  2025-05-12 23:43:15 | morai.experience.charters | INFO     | The weights list is 1 long and should be 3 long. Using the first weight for all weights.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1211b9a2-435d-4357-84fb-11664b5671b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1211b9a2-435d-4357-84fb-11664b5671b1")) {                    Plotly.newPlot(                        "1211b9a2-435d-4357-84fb-11664b5671b1",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death_count","x":{"dtype":"i4","bdata":""},"y":{"dtype":"f8","bdata":
| morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration', 'sex', 'smoker_status', 'binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
import xgboost as xgb
from xgboost import XGBRegressor

if model_build:
    model = XGBRegressor(
        objective="reg:squarederror",
        eval_metric="rmse",
        max_depth=6,
        eta=0.05,
        subsample=0.8,
        colsample_bytree=0.5,
        enable_categorical=True,
    )

    model.fit(X_train, y_train, sample_weight=weights_train)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:43:23 | __main__ | INFO     | saved model 'xgb'. type: <class 'xgboost.sklearn.XGBRegressor'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:43:28 | morai.forecast.metrics | INFO     | Adding model 'xgb'

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="0d87725c-6a35-4e2c-8fca-d9a919131fd5" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0d87725c-6a35-4e2c-8fca-d9a919131fd5")) {                    Plotly.newPlot(                        "0d87725c-6a35-4e2c-8fca-d9a919131fd5",                        [{"hovertemplate":"feature=%{x}\u003cbr\u003eimportance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["attained_age","smoker_status","duration","class_enh","insurance_plan","binned_face","sex","observation_year"],"xaxis":"x","y":{"dtype":"f4","bdata":"cuEAP5JI6z3NCK09Z\u002fmfPQzyhz3lc4Y9E+RUPVqjDz0="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatte ...

# %%
charters.compare_rates(
    model_data,
    x_axis="insurance_plan",
    rates=["qx_raw", "qx_xgb", "qx_vbt15"],
    weights=["amount_exposed"],
    secondary="death_count",
)
# Out:
#  2025-05-12 23:43:29 | morai.experience.charters | INFO     | The weights list is 1 long and should be 3 long. Using the first weight for all weights.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="8a51de09-dfb2-4703-a2be-5b91ed8f088b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8a51de09-dfb2-4703-a2be-5b91ed8f088b")) {                    Plotly.newPlot(                        "8a51de09-dfb2-4703-a2be-5b91ed8f088b",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"death_count","x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"AAAAAABW8UAAAAAAwKbWQAAAAAAAm+NAAAAAAADfwkAAAAAAAHG5QAAAAAAA\u002fqdA"},"type":"bar","xaxis":"x","yaxis":"y2"},{"mode":"lines+markers","name":"qx_raw","x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"eqtCJq6ihT\u002fZETnfI+NhP2E0Pi2hRY0\u002fDTFeGX4PgD\u002fQQwKVIRV7PzvXU3HbM3Q\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"qx_xgb","x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"7xW41+A8hj+rdZw\u002fhI5hPyZM\u002fHJGpY0\u002fO\u002fnvbUDBfz9IM1xGN5p7P+0fzM70zXM\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"qx_vbt15","x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"NV8oIjt5hj+T+schLhpmPxsszBNzC4w\u002fCtacIxcVhD8L1sT\u002fi8J7P53gInRtNHM\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"ma ...

# %%
charters.target(
    df=model_data,
    target="ratio",
    cols=3,
    features=model_features,
    numerator=["death_claim_amount"],
    denominator=["exp_amt_xgb"],
).show()
# Out:
#  2025-05-12 23:43:29 | morai.experience.charters | INFO     | Creating '9' target plots.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="79bb5d6d-ead2-4e1b-bba7-a516263f33cb" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById
type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"s3GuRhwi7z\u002fGw8zEHk3wP5mQMSjCmO8\u002fOvJ3fjov8D\u002fui5hZtmXvP\u002fjJJU1TUvA\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata": ...

# %%
# lgb.plot_tree(bst, tree_index=0, figsize=(20, 10))
# plt.show()

# %% [markdown]
# ## CatBoost

# %% [markdown]
# **Overview**
# - A CatBoost model is an ensemble of decision trees that are boosted. It is very good with non-linear data, but does not extrapolate well.
#
# **Feature Preprocessing:**
# - CatBoost doesn't need all numeric variables and can handle categorical

# %%
model_name = "cat"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    preset="pass",
)
# Out:
#  2025-05-12 23:43:30 | morai.forecast.preprocessors | INFO     | using 'pass' preset which makes all features passthrough
#  2025-05-12 23:43:30 | morai.forecast.preprocessors | INFO     | model target: ['qx_raw']
#  2025-05-12 23:43:30 | morai.forecast.preprocessors | INFO     | model weights: ['amount_exposed']
#  2025-05-12 23:43:30 | morai.forecast.preprocessors | INFO     | passthrough - (generally numeric): ['attained_age', 'observation_year', 'duration', 'sex', 'smoker_status', 'binned_face', 'class_enh', 'insurance_plan']

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
cat_features = feature_dict["ordinal"] + feature_dict["ohe"] + feature_dict["nominal"]
cat_features = list(set(cat_features) & set(model_features))

# %%
from catboost import CatBoostRegressor

if model_build:
    model = CatBoostRegressor(
        iterations=2000,
        learning_rate=0.05,
        depth=8,
        cat_features=cat_features,
        one_hot_max_size=11,
    )
    model.fit(X_train, y_train, sample_weight=weights_train, verbose=0)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.get_params())
# Out:
#  2025-05-12 23:47:17 | __main__ | INFO     | saved model 'cat'. type: <class 'catboost.core.CatBoostRegressor'>

# %%
predictions = model.predict(X)

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
importance = base.ModelWrapper(model).get_importance()

# %%
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)
# Out:
#  2025-05-12 23:47:20 | morai.forecast.metrics | INFO     | Adding model 'cat'

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="15abcfbc-e790-4b56-99a5-795e73ab7e25" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("15abcfbc-e790-4b56-99a5-795e73ab7e25")) {                    Plotly.newPlot(                        "15abcfbc-e790-4b56-99a5-795e73ab7e25",                        [{"hovertemplate":"feature=%{x}\u003cbr\u003eimportance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["attained_age","duration","class_enh","binned_face","observation_year","insurance_plan","sex","smoker_status"],"xaxis":"x","y":{"dtype":"f8","bdata":"Ueo+AOCLQkDSzTgcQrYrQAcYBuHUzChAJj9tGfLEJEBB3hPO9VwkQLPoUZjZFyFAeuFMULL6FUAw6C9nOVkAQA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":
type":"scatter","xaxis":"x3","yaxis":"y3"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i4","bdata":"AQAAAAIAAAADAAAABAAAAAUAAAAGAAAABwAAAAgAAAAJAAAACgAAAAsAAAAMAAAADQAAAA4AAAAPAAAAEAAAABEAAAASAAAAEwAAABQAAAAVAAAAFgAAABcAAAAYAAAAGQAAABoAAAAbAAAAHAAAAB0AAAAeAAAAHwAAACAAAAAhAAAAIgAAACMAAAAkAAAAJQAAACYAAAAnAAAA"},"y":{"dtype":"f8","bdata":"W4edguZ07j8Eh9vr6yzwP9kqwaMjY\u002fA\u002faKxE51858D8evNmCdhzvP8QYcEGEQPA\u002f\u002fczdnhxa7z82EahgSpjuP+IIrA8BMe4\u002fWTqEBHF\u002f8D85VLEyLW\u002fwP485Yd\u002fzyu8\u002fIyXnqTL57z+N4ErXDmfvP0xif\u002f1hdPA\u002f31Iim6jN7z9PFTduNT\u002fwPxevOspwHvA\u002fjcgGr0X97z+Pisd6r4PwP37Ub1WAv+8\u002fik44aKmO7z+POhRVv8fvPwgwVfDLPe8\u002fDd3RQNJY8D+uh7vCW8vuPx1XOizOr\u002fA\u002fcpn\u002f\u002fNXV7z9QPvcVwWPwPxoaVPpvjO8\u002fe4XjlGKy7z\u002fW9iZpVkzvP\u002f44CkHwpPA\u002fbSs+nG7W7j\u002fJzggPj5TvP7w2hrqcde8\u002f5w+vXkYm7z8HLUGKLr\u002fwP3D2sjiBJe0\u002f"},"type":"scatter","xaxis":"x4","yaxis":"y4"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":["Perm","Term","UL","ULSG","VL","VLSG"],"y":{"dtype":"f8","bdata":"L5OZjcXo7z\u002fnC\u002fm73ADwP09Dq4v8V+8\u002fLNNS3+988D\u002fjGCxpgkzvPw4Gs38mA\u002fA\u002f"},"type":"scatter","xaxis":"x5","yaxis":"y5"},{"line":{"color":"#1F77B4"},"mode":"lines","name":"ratio_0","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bd ...

# %% [markdown]
# ## Lee Carter

# %% [markdown]
# The Lee-Carter model is formulated as follows:
#
# $$\log(m_{x,t}) = a_{x} + b_{x}k_{t} + \epsilon_{x,t}$$
#
# source: https://en.wikipedia.org/wiki/Lee%E2%80%93Carter_model
#
# Where:
# - $m_{x,t}$ is the _matrix mortality rate_ at age $x$ in year $t$
# - $a_{x}$ describes the general _shape_ of mortality at age $x$ (mean of the time-averaged logs of the central mortality rate at age $x$). This is known as the _age effect_ on mortality.
# - $b_{x}$ measures the change in the rates at age $x$ due to a change in the underlying time trend, $k_{t}$.
# - $k_{t}$ reflects the effect of the time trend, $t$, on mortality.
# - $\epsilon_{x,t}$ are i.i.d. normal random variables with zero means and constant variance, $\sigma^{2}$.

# %%
model_name = "lc"

# %%
model_params = {"weights": True}
model = base.LeeCarter()
# Out:
#  2025-05-13 00:02:31 | morai.models.base | INFO     | initialized LeeCarter

# %%
lc_df = model.structure_df(model_data)
# Out:
#  2025-05-13 00:02:31 | morai.models.base | INFO     | grouping data by age and year
#  2025-05-13 00:02:31 | morai.models.base | INFO     | calculating qx_raw rates using death_claim_amount and amount_exposed
#  2025-05-13 00:02:31 | morai.models.base | INFO     | floored 50 rates to 0.000001 and capped 0 rates to 0.999999.
#  2025-05-13 00:02:31 | morai.models.base | INFO     | crude_df shape: (488, 5)

# %%
lc_df = model.fit(lc_df)
# Out:
#  2025-05-13 00:02:31 | morai.models.base | INFO     | creating Lee Carter model with qx_raw rates...
#  2025-05-13 00:02:31 | morai.models.base | INFO     | age range: 50, 113
#  2025-05-13 00:02:31 | morai.models.base | INFO     | year range: 2012, 2019
#  2025-05-13 00:02:31 | morai.models.base | INFO     | creating `1` intervals
#  2025-05-13 00:02:31 | morai.models.base | INFO     | adding qx_lc to lc_df

# %%
model_data = model.map(model_data)
# Out:
#  2025-05-13 00:02:32 | morai.models.base | INFO     | mapping qx_lc to df

# %%
lcf_df = model.forecast(years=5)
# Out:
#  2025-05-13 00:02:33 | morai.models.base | INFO     | forecasting qx_lc using deterministic random walk...

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
scorecard = model_results.get_scorecard(
    y_true_train=model_data["death_claim_amount"],
    y_pred_train=model_data[f"exp_amt_{model_name}"],
    weights_train=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=None,
    model_params=model_params,
    scorecard=scorecard,
    importance=None,
)
# Out:
#  2025-05-13 00:02:33 | morai.forecast.metrics | ERROR    | Model name lc already exists, not adding model. Please use a different name.

# %% [markdown]
# Average log qx shows that mortality rates increase by age

# %%
charters.chart(
    df=pd.DataFrame(model.a_x).set_axis([0], axis=1).reset_index(),
    x_axis="attained_age",
    y_axis=0,
    color=None,
    type="line",
    title="Average of log(qx)",
    labels={"attained_age": "attained_age", "0": "log_qx"},
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4f406ed9-0ca0-4009-9e85-27447f89f7ae" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4f406ed9-0ca0-4009-9e85-27447f89f7ae")) {                    Plotly.newPlot(                        "4f406ed9-0ca0-4009-9e85-27447f89f7ae",                        [{"hovertemplate":"attained_age=%{x}\u003cbr\u003elog_qx=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i4","bdata":""},"xaxis":"x","y":{"dtype":"f8","bdata":"+l9d1fgmHMCQ6Lckec8bwOh6W267iRvA8atgdzleG8CUCzYXhiwawMIXE9z\u002fMRrAZH\u002fxwyRJGcBmmuO6Oi8ZwJhugxWtyhjAqpA5OKYhGMBOxa\u002fcM80XwBUqcL938RfATVJVi2heF8BSbcCSobsWwM6KcW4BJxbA5GXJ4pJhFcDGSYzjIoMVwMJYAYr6ABXAUNn\u002fotd7FMAqbRTmEf4TwGYB5IoDYBPAcuBE6JnLEsDo3CALPmISwKqNFYgQJhLASKY+4VpqEcC5mUmvSb4QwGrpjEMIORDAkkm3MXBxD8BQeEI6CSgPwJ9UzVl8Qg\u002fA0uXUvrwnDcD2M1ijg0gMwORPwSMMtgvAVCogEDo8C8AQcKr7nacIwLKlpMnbhQjAlkySuqQOB8Ccnt63tlQFwCvRVCm4qwTAcX3jqZybA8D44fn621ICwLgQ2xI\u002fz\u002f6\u002fOWJOYx4VAcAxlqDKlAT\u002fvwM9HPm1P\u002fy\u002fijjcLSc7+b8qkOmS25\u002f9v8AvY85K\u002ffa\u002fSjKAmqZO9L\u002f6DcxFN4r8v9+c78e\u002f2\u002fq\u002f9uo7mWWtCcBIjkAv78n6v2+31qLNfBTACQ6haCDyH8BJIjQtoDMlwMnCvD\u002f1HCnANVEeXqGYJcCg\u002f4+ZiqErwKD\u002fj5mKoSvAoP+PmYqhK8Cg\u002f4+ZiqErwKD\u002fj5mKoSvAoP+PmYqhK8A="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0. ...

# %%
charters.chart(
    df=pd.DataFrame(model.k_t).set_axis([0], axis=1).reset_index(),
    x_axis="observation_year",
    y_axis=0,
    color=None,
    type="line",
    title="Time Trend of Mortality",
    labels={"observation_year": "observation_year", "0": "k_t"},
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="b7aba306-bdb1-4aa7-87b8-98957a7c729d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b7aba306-bdb1-4aa7-87b8-98957a7c729d")) {                    Plotly.newPlot(                        "b7aba306-bdb1-4aa7-87b8-98957a7c729d",                        [{"hovertemplate":"observation_year=%{x}\u003cbr\u003ek_t=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"SN669lHQNsBMgblfipkaQMVgChthkyTAJ8wQ7SNZMMAQvTc3sDTov4R7gOmlSgXA9AC5ga8FL0BZx29X5rQ+QA=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d": ...

# %%
charters.chart(
    df=pd.DataFrame(model.b_x).set_axis([0], axis=1).reset_index(),
    x_axis="attained_age",
    y_axis=0,
    color=None,
    type="line",
    title="Change in the Rate per Age with Respect to each Year",
    labels={"attained_age": "attained_age", "0": "b_x"},
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2357b68b-e232-4ff4-935b-244c3bda8f91" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2357b68b-e232-4ff4-935b-244c3bda8f91")) {                    Plotly.newPlot(                        "2357b68b-e232-4ff4-935b-244c3bda8f91",                        [{"hovertemplate":"attained_age=%{x}\u003cbr\u003eb_x=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i4","bdata":""},"xaxis":"x","y":{"dtype":"f8","bdata":"I7YuNK2PbL+TA+4O6ZRzv0dxzGd0DIK\u002f\u002f+piLOJNRT8POHAMJKh1P9kZ6oeslmE\u002fwoGNydM0bb8N3bkNAsBzvyGFX0a192K\u002fzNZiD4PFfL8z\u002fu\u002f1C2V3P2nxY2RDWE2\u002f\u002fpl3iihkKL+HTu+6LItSP+2A97pQfy4\u002frYqdr4z+Yr9su\u002fMDGLpbPzI6dmhsdWq\u002fFU71QPRtXj+etPAJxGQ+v6cglxvsRmW\u002f0n\u002fJu8oMXT+LH+OaESM7Pz3KgMEvJQm\u002fLVCygZ9AcD92n29f7D1QP\u002fw\u002fIxYHOFK\u002f2nW25bpUbz8P86WY8ENTvwWWHA5Om4c\u002fdHjCEeCfSr\u002fOpDnZcsNmP95c0MGZEnQ\u002fgpIL2AgecD+cMXql0Y5ZP2utPs9nxXQ\u002fSvQ297TXRj9EMAp4FqN1v9rQQieS4mw\u002ftKhjAVf0TD9k5xPzQuKGvxdMh5xFNFq\u002fyFp29ZIdYL8eoZlubpdVP1ljDBoMfVK\u002f977VVkEsUT8hcRP1XuuIPw+0b7dnIYm\u002fXPuvH5fjZT\u002fsEhiIXuyDv0\u002fC02ZIz30\u002fHxEQ0XhHwT9NVCnwYEOXv9eyUacqQNE\u002fmlvDUWMawz93DjM030jSP1udadV5G6A\u002f3SB33RCnwz8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0 ...

# %%
charters.compare_rates(
    model_data,
    x_axis="observation_year",
    rates=["qx_raw", "qx_lc"],
    weights=["amount_exposed"],
    secondary="amount_exposed",
)
# Out:
#  2025-05-12 23:50:23 | morai.experience.charters | INFO     | The weights list is 1 long and should be 2 long. Using the first weight for all weights.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a3f8c27d-17ad-4e5e-be32-320bd36450b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a3f8c27d-17ad-4e5e-be32-320bd36450b6")) {                    Plotly.newPlot(                        "a3f8c27d-17ad-4e5e-be32-320bd36450b6",                        [{"marker":{"color":"rgba(135, 206, 250, 0.6)"},"name":"amount_exposed","x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata":"mBvnWqfwV0I4ICnInLJaQpZ4FD0KV1xCF0gVPNyBXkKFZHiRPBxgQvrfuRse8GBCSfIRku84YkIRtl+pJbFiQg=="},"type":"bar","xaxis":"x","yaxis":"y2"},{"mode":"lines+markers","name":"qx_raw","x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata":"VqHybBe7cT8ENEVsSeZyP2vHsHcOo3M\u002fNxZAu30ocz\u002fYEZ+49yJzP\u002f5UoTq6u3M\u002f7SFTh+8HdD8pFxfBX5F1Pw=="},"type":"scatter","xaxis":"x","yaxis":"y"},{"mode":"lines+markers","name":"qx_lc","x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjBw=="},"y":{"dtype":"f8","bdata":"5nJOSDA1cj\u002fMl2\u002fW4a9yP+mDHdZa73M\u002f5CQXDVD4cj85uxVJjnVzPyFvUZ9GeHM\u002fKSuhTgLxcz+5iB85nY51Pw=="},"type":"scatter","xaxis":"x","yaxis":"y"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":" ...

# %% [markdown]
# ## Cairns-Blake-Dowd Model

# %% [markdown]
# The Cairns-Blake-Dowd (CBD) model is a stochastic mortality model, and a variant of the Lee-Carter mortality model. It is designed with longevity risk in mind, particularly attempting to understand and forecast mortality at older ages.
#
# The model is in the following form:
#
# $$\text{logit}(_{t}q_{x}) = \kappa_{t}^{(1)} + (x - \bar{x})\kappa_{t}^{(2)}$$
#
# - $\text{logit}(\alpha) = \log\big(\frac{\alpha}{1-\alpha}\big)$
# - $\kappa_{t}^{(1)}$  is the _level_ factor, varying with respect to year $t \in (t_{1}, t_{2}, \dots, t_{q})$
# - $\kappa_{t}^{(2)}$  is the _slope_ factor, varying with respect to year $t \in (t_{1}, t_{2}, \dots, t_{q})$
# - $x$ is the age group, $x \in (x_{1}, x_{2}, \dots, x_{p})$
# - $\bar{x}$ is the average of the age group
# - $_{t}q_{x}$ is the probability an individual aged $x$ last birthday dies before age $x+t$
#
# We will be using method of least-squares to get estimates $\hat{\kappa}^{(1)}$ and $\hat{\kappa}^{(2)}$.
#
# Further information:
# - https://www.actuaries.org/AFIR/Colloquia/Rome2/Cairns_Blake_Dowd.pdf - further discussion on the merits of the CBD model (such as age-period cohort effects and further extensions to the CBD model).

# %%
model_name = "cbd"

# %%
model_params = {"weights": True}
model = base.CBD()
# Out:
#  2025-05-12 23:54:11 | morai.models.base | INFO     | initialized CBD

# %%
cbd_df = model.structure_df(model_data)
# Out:
#  2025-05-12 23:54:11 | morai.models.base | INFO     | grouping data by age and year
#  2025-05-12 23:54:11 | morai.models.base | INFO     | calculating qx_raw rates using death_claim_amount and amount_exposed
#  2025-05-12 23:54:11 | morai.models.base | INFO     | floored 50 rates to 0.000001 and capped 0 rates to 0.999999.
#  2025-05-12 23:54:11 | morai.models.base | INFO     | cbd_df shape: (488, 5)

# %%
cbd_df = model.fit(cbd_df)
# Out:
#  2025-05-12 23:54:11 | morai.models.base | INFO     | creating CBD model with qx_raw rates...
#  2025-05-12 23:54:11 | morai.models.base | INFO     | age range: 50, 113
#  2025-05-12 23:54:11 | morai.models.base | INFO     | year range: 2012, 2019
#  2025-05-12 23:54:11 | morai.models.base | INFO     | creating `1` intervals
#  2025-05-12 23:54:11 | morai.models.base | INFO     | adding qx_cbd to cbd_df

# %%
model_data = model.map(model_data)
# Out:
#  2025-05-12 23:54:12 | morai.models.base | INFO     | mapping qx_cbd to df

# %%
cbdf_df = model.forecast(years=5)
# Out:
#  2025-05-12 23:54:13 | morai.models.base | INFO     | forecasting qx_cbd using deterministic random walk...

# %%
model_data = experience.calc_qx_exp_ae(
    model_data=model_data,
    predictions=predictions,
    model_name=model_name,
    exposure_col="amount_exposed",
    actual_col="death_claim_amount",
)

# %%
scorecard = model_results.get_scorecard(
    y_true_train=model_data["death_claim_amount"],
    y_pred_train=model_data[f"exp_amt_{model_name}"],
    weights_train=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=None,
    model_params=model_params,
    scorecard=scorecard,
    importance=None,
)
# Out:
#  2025-05-12 23:54:15 | morai.forecast.metrics | INFO     | Adding model 'cbd'

# %%
# shape shows the impact of time on mortality
charters.chart(
    df=pd.concat([pd.DataFrame(model.k_t_1).set_axis([0], axis=1), pd.DataFrame(model.k_1_f).set_axis([0], axis=1)]).reset_index(),
    x_axis=model.year_col,
    y_axis=0,
    color=None,
    type="line",
    title="Shape Component by year",
    labels={"0": "k_t_1"},
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="4da1fc51-29e7-4aac-88e0-5a939310153d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("4da1fc51-29e7-4aac-88e0-5a939310153d")) {                    Plotly.newPlot(                        "4da1fc51-29e7-4aac-88e0-5a939310153d",                        [{"hovertemplate":"observation_year=%{x}\u003cbr\u003ek_t_1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjB+QH5QfmB+cH6Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"fFQES5BEFMAResdQt8ESwBkNAyGssRXAVqE6b4YDFsCfooNLiaMVwCxP5pDCSRLA56WbYq81EsAAYOjQqZsRwHDhpAGNRhHA4WJhMnDxEMBS5B1jU5wQwMJl2pM2RxDAZc4tiTPkD8A="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl", ...

# %%
# slope shows if the impact of time is different by year
charters.chart(
    df=pd.concat([pd.DataFrame(model.k_t_2).set_axis([0], axis=1), pd.DataFrame(model.k_2_f).set_axis([0], axis=1)]).reset_index(),
    x_axis=model.year_col,
    y_axis=0,
    color=None,
    type="line",
    title="Slope Component by year",
    labels={"0": "k_t_2"},
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="e6735070-37f7-4158-b482-a3c7d3c18cc6" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e6735070-37f7-4158-b482-a3c7d3c18cc6")) {                    Plotly.newPlot(                        "e6735070-37f7-4158-b482-a3c7d3c18cc6",                        [{"hovertemplate":"observation_year=%{x}\u003cbr\u003ek_t_2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"3AfdB94H3wfgB+EH4gfjB+QH5QfmB+cH6Ac="},"xaxis":"x","y":{"dtype":"f8","bdata":"OOpB\u002f3kDoD9PtZeDLvqkP7yIXDfKeaC\u002fYoSxQpTPo7+PZuF6oyqjv2lqZLKhPrE\u002f5jQ7FR1xqz8SLXxk5zSsP211IxEVu60\u002fyL3KvUJBrz8SAzk1uGOwP0CnjAvPJrE\u002fbUvg4eXpsT8="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scatter ...

# %%
charters.compare_rates(
    model_data,
    x_axis="observation_year",
    rates=["qx_raw", "qx_cbd"],
    weights=["amount_exposed"],
    secondary="amount_exposed",
)

# %% [markdown]
# # Model Results

# %%
original_float_format = pd.options.display.float_format
pd.options.display.float_format = "{:,.6f}".format  # Increase to 10 decimal places
model_results.scorecard.sort_values(by=("test", "r2_score"), ascending=False)
# Out:
#    model_name    train                                                      \
#                     ae    smape  r2_score root_mean_squared_error    shape
# 5         gbm 1.000000 1.926381  0.130311          208,125.455513   877381
# 4         gam 1.000000 1.924616  0.101464          211,548.931163   877381
# 10        glm 1.000000 1.924590  0.096490          212,133.664346   877381
# 6         xgb 1.000564 1.924258  0.189317          200,941.049357   877381
# 2        tree 1.006885 1.928945  0.090978          212,779.831784   877381
# 3          rf 1.007973 1.917206  0.073377          214,829.864796   877381
# 7         cat 1.000031 1.922730  0.441500          166,784.091283   877381
# 1          lr 1.004714 1.930634 -0.029726          226,466.484193   877381
# 0       vbt15 0.898235 1.926877  0.097066          206,603.606989  1096727
# 8          lc 0.998724 1.923082  0.381053          171,055.283069  1096727
# 9         cbd 0.998724 1.923082  0.381053          171,055.283069  1096727
#
#        test                                                            \
#          ae    smape  r2_score root_mean_squared_error          shape
# 5  0.990595 1.927327  0.130525          179,706.464012 219,346.000000
# 4  0.985262 1.925667  0.124703          180,307.107580 219,346.000000
# 10 0.983754 1.925512  0.121722          180,613.821923 219,346.000000
# 6  0.989847 1.925081  0.118889          180,904.935748 219,346.000000
# 2  0.991037 1.929929  0.085698          184,280.751559 219,346.000000
# 3  0.991936 1.918309  0.071365          185,719.511591 219,346.000000
# 7  0.993435 1.924492  0.056825          187,167.831566 219,346.000000
# 1  0.981576 1.930753 -0.041418          196,674.257615 219,346.000000
# 0       NaN      NaN       NaN                     NaN            NaN
# 8       NaN      NaN       NaN                     NaN            NaN
# 9       NaN      NaN       NaN                     NaN            NaN
#
#                     train                   test
#                       aic                    aic
# 5                     NaN                    NaN
# 4                     NaN                    NaN
# 10 150,782,682,356.605621 150,782,682,356.605621
# 6                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 7                     NaN                    NaN
# 1                     NaN                    NaN
# 0                     NaN                    NaN
# 8                     NaN                    NaN
# 9                     NaN                    NaN

# %%
pd.options.display.float_format = original_float_format

# %%
break

# %%
# write out results
model_results.save_model()
model_data.to_parquet("files/dataset/model_data.parquet")
# Out:
#  2025-05-13 00:07:17 | morai.forecast.metrics | INFO     | saving results to C:\Users\johnk\Desktop\github\morai\files\result\model_results.json

# %%
# model_results = metrics.ModelResults(filepath='model_results.json')

# %%
rank_df = metrics.ae_rank(
    df=model_data[model_data["insurance_plan"].isin(["UL", "ULSG"])],
    features=model_features,
    actuals="death_claim_amount",
    expecteds="exp_amt_vbt15",
    exposures="amount_exposed",
)
rank_df.head()

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Chart

# %%
charters.chart(
    df=model_data,
    x_axis="attained_age",
    y_axis="ratio",
    color=None,
    type="line",
    numerator="death_claim_amount",
    denominator="amount_exposed",
)
# Out:
#  2025-05-13 00:07:29 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [amount_exposed]
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="16083e65-b766-43b4-a843-2a25b4d59e69" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("16083e65-b766-43b4-a843-2a25b4d59e69")) {                    Plotly.newPlot(                        "16083e65-b766-43b4-a843-2a25b4d59e69",                        [{"hovertemplate":"attained_age=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i4","bdata":""},"xaxis":"x","y":{"dtype":"f8","bdata":"7zjQLXfyTD+F9ZaisuxPPwskcbrq4VA\u002foJWJdxwJUj\u002fZvGNW96FYPzOip7GN71c\u002fwsXyNBOFXz9lWiNRxxJeP56kOjYytGA\u002fn2aHzuOAYz8W9UXeURFmP9RmuAc9kWQ\u002fdp8wckSsZz\u002fOVpK7hflrPy7iC5WUP3A\u002fmoRUg3qRcz8FTkna0QNzP6j1E6FkJHU\u002fJlAiTc+ReD8mRrqidqB7PxBmbTubEYA\u002fHVWnsmnUgj\u002fftMlVm8KEP9C+UsCM1oU\u002fuORboBGMij85wcRpelaPPzyD2BI\u002f95E\u002fOuYYVOBplD\u002fvtuR+BcWUP8NYE61QO5U\u002fwg5Tvxjdmj8NiAPnOI2ePxdtPbgaNaA\u002fZP1eTe9ZoT87z3aqvXqoP7tIomAmHqk\u002foY1\u002faQ8qrT8ScdG+g4+xP6YZF9H7ArQ\u002fOT6OEn3Gtj\u002fiSoWuhVi4P+hyd0k2dMM\u002fHHtamUhNvj9nMUoX+hLDP8+XULfsV8c\u002f44OJc2zNyz9xY1k\u002fHVXHP\u002fzAltyRvMs\u002fhwPXWrSG1j8ytMhXSd7HP2VhABUMv8w\u002f5NxMnXRY1z9z6BlSQwPJPyYPb3kg2Ng\u002fDmiEgUhesD+Lp\u002f2xYonEP7K6MJUF8WU\u002fHIYaV50Uqz8AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %%
charters.chart(
    df=model_data,
    x_axis="duration",
    y_axis="ratio",
    color="face_amount_band",
    numerator="death_claim_amount",
    denominator="amount_exposed",
    x_bins=5,
    type="line",
)
# Out:
#  2025-05-13 00:07:33 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [amount_exposed]
#  2025-05-13 00:07:33 | morai.experience.charters | INFO     | Binning feature: [duration] with 5 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="2b6b4c54-91d1-4792-a514-3214a7174e2b" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2b6b4c54-91d1-4792-a514-3214a7174e2b")) {                    Plotly.newPlot(                        "2b6b4c54-91d1-4792-a514-3214a7174e2b",                        [{"hovertemplate":"face_amount_band=01: 0 - 9,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"01: 0 - 9,999","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"01: 0 - 9,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"9VHBcJsvfj8WX1KjM5uiPzCYaxknaag\u002frdqylmTOrD\u002fmyoiB4IyQPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=02: 10,000 - 24,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"02: 10,000 - 24,999","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"02: 10,000 - 24,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"csAdSMd6gD+SUqOrFw2WPyUHmlJ+taA\u002fIbx6PO+7oT\u002f+38Gb3UWNPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=03: 25,000 - 49,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"03: 25,000 - 49,999","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"03: 25,000 - 49,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"4IEPkd3WeD+RKIpoFVOQP1xS9yOkOZY\u002f7dNzHHWXmj\u002fbrGFFBuWHPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=04: 50,000 - 99,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"04: 50,000 - 99,999","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"04: 50,000 - 99,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"oN8aVrdWcT+aSFhgffeEPyo72oANMpA\u002fqOeSJRtrlj+NlpObK1iBPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=05: 100,000 - 249,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"05: 100,000 - 249,999","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"05: 100,000 - 249,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"ULJqKThuZD9bIvB8WVV5P\u002ft2MvR3eIk\u002fBxvR+UlFlz\u002fboT7Zf2JzPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=06: 250,000 - 499,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"06: 250,000 - 499,999","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"06: 250,000 - 499,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"dHsj0eiCWz\u002fFqefQAhZzP\u002fmFEALlm4o\u002fnXy9UG2umD9GXC3WQAJqPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"face_amount_band=07: 500,000 - 999,999\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"07: 500,000 - 999,999","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"07: 500,000 - 999,999","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-3 ...

# %%
charters.chart(
    df=model_data[
        (model_data["attained_age"] > 50)
        & (model_data["attained_age"] < 90)
        & (model_data["insurance_plan"].isin(["Term", "UL", "Perm", "ULSG"]))
    ],
    x_axis="duration",
    color="insurance_plan",
    y_axis="ratio",
    type="line",
    numerator="death_claim_amount",
    denominator="amount_exposed",
    x_bins=5,
)
# Out:
#  2025-05-13 00:07:36 | morai.experience.charters | INFO     | Calculating ratio using [death_claim_amount] and [amount_exposed]
#  2025-05-13 00:07:36 | morai.experience.charters | INFO     | Binning feature: [duration] with 5 bins
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="61847df1-ec95-43e3-b34f-744a017dea0f" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("61847df1-ec95-43e3-b34f-744a017dea0f")) {                    Plotly.newPlot(                        "61847df1-ec95-43e3-b34f-744a017dea0f",                        [{"hovertemplate":"insurance_plan=Perm\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Perm","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Perm","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"u0LBEcNKYD8PVSqdM+qBP9lxcVDHso0\u002fathd0ut9lj8knuQX7fdxPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"insurance_plan=Term\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Term","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Term","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"wFUJ5P0bWz9fNFtYIvpnP3UpSHchMnw\u002fJGJ\u002fBRy8iz8KnDSB1NpjPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"insurance_plan=UL\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UL","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"UL","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"boTkxJptbD8ZeGyisFWJP2oGO7t0K5A\u002ffSmEx0uJlj9aEFL2NdyNPw=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"insurance_plan=ULSG\u003cbr\u003eduration=%{x}\u003cbr\u003eratio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ULSG","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ULSG","orientation":"v","showlegend":true,"x":["1-7","16-23","24-31","32-39","8-15"],"xaxis":"x","y":{"dtype":"f8","bdata":"mtAQ7KezZj\u002f9sDepC1+NP9hqPwhY440\u002f8fJ9WftZlz9SEhdJ0wiHPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# This shows that as duration goes up the class structure becomes more NA preferred class structure which has poor a/e

# %% [markdown]
# ## Compare

# %%
charters.compare_rates(
    df=model_data[model_data["insurance_plan"].isin(["UL", "ULSG"])],
    x_axis="class_enh",
    rates=["ae_vbt15"],
    weights=["exp_amt_vbt15"],
    secondary="death_count",
    display=True,
)

# %%
charters.chart(
    df=model_data[model_data["insurance_plan"].isin(["UL", "ULSG"])],
    x_axis="duration",
    y_axis="death_count",
    color="number_of_pfd_classes",
    x_bins=5,
    type="bar",
)

# %% [markdown]
# This shows the product sales by year

# %%
charters.chart(
    df=model_data,
    x_axis="issue_year",
    y_axis="policies_exposed",
    color="insurance_plan",
    type="bar",
)

# %%
charters.chart(
    df=model_data,
    x_axis="observation_year",
    y_axis="policies_exposed",
    color="number_of_pfd_classes",
    type="bar",
)

# %%
# charters.scatter(df=df, target="qx_raw", numeric=True, sample_nbr=1000).show()

# %% [markdown]
# ## PDP

# %%
charters.pdp(
    model=GLM.model,
    df=md_encoded,
    x_axis="insurance_plan",
    mapping=mapping,
    weight="amount_exposed",
)

# %% [markdown]
# This shows that the perm product is not too high when accounting for the other variables

# %%
charters.pdp(
    model=model,
    df=md_encoded,
    x_axis="insurance_plan",
    weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
)

# %% [markdown]
# This shows that for a 4 class system there seems to be wear-off of underwriting, but does persist in later ages

# %%
charters.pdp(
    model=model,
    df=md_encoded[
        (
            md_encoded["class_enh"].isin(["2_1", "2_2"])
            & (md_encoded["insurance_plan"] == "UL")
            & (md_encoded["attained_age"] >= 65)
            & (md_encoded["attained_age"] <= 90)
        )
    ],
    x_axis="attained_age",
    line_color="class_enh",
    weight="amount_exposed",
    mapping=mapping,
    center="per_x",
    secondary="death_count",
    display=True,
    n_jobs=-1,
)

# %%
charters.pdp(
    model=model,
    df=md_encoded[
        (
            md_encoded["class_enh"].isin(["2_1", "2_2"])
            & (md_encoded["insurance_plan"] == "UL")
            & (md_encoded["duration"] <= 30)
        )
    ],
    x_axis="duration",
    line_color="class_enh",
    weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    center="per_x",
    display=True,
    n_jobs=-1,
)

# %% [markdown]
# This shows there may be something with the data that there is an uptick in 2019. It also shows a similar pattern for all the products. Granted it is a random forest model so there may be some influence in the prediction

# %%
charters.pdp(
    model=model,
    df=md_encoded,
    x_axis="observation_year",
    line_color="insurance_plan",
    weight="amount_exposed",
    secondary="death_count",
    mapping=mapping,
    display=True,
    n_jobs=-1,
)

# %% [markdown]
# # Reload

# %%
importlib.reload(charters)

# %%
importlib.reload(custom_logger)

# %%
importlib.reload(models)
# Out:
# <module 'morai.forecast.models' from 'C:\\Users\\johnk\\Desktop\\github\\morai\\morai\\forecast\\models.py'>

# %%
importlib.reload(helpers)
# Out:
# <module 'morai.utils.helpers' from 'C:\\Users\\johnk\\Desktop\\github\\morai\\morai\\utils\\helpers.py'>

# %%
importlib.reload(metrics)
# Out:
# <module 'morai.forecast.metrics' from 'C:\\Users\\johnk\\Desktop\\github\\morai\\morai\\forecast\\metrics.py'>

# %%
importlib.reload(preprocessors)
# Out:
# <module 'morai.forecast.preprocessors' from 'C:\\Users\\johnk\\Desktop\\github\\morai\\morai\\forecast\\preprocessors.py'>

# %% [markdown]
# # Utilities

# %%
jupyter_objects = helpers.memory_usage_jupyter()
jupyter_objects
# Out:
#                object  size_mb
# 0          model_data   394.32
# 1          md_encoded   388.04
# 2                   X    49.16
# 3             X_train    46.02
# 4       weights_train    13.39
# ..                ...      ...
# 60         model_name     0.00
# 61  initial_row_count     0.00
# 62         model_save     0.00
# 63         model_load     0.00
# 64        model_build     0.00
#
# [65 rows x 2 columns]

# %%
helpers.delete_jupyter_objects(objects=list(jupyter_objects["object"]))

# %% [markdown]
# # Unused Models

# %% [markdown]
# ## LightGBM

# %% [markdown]
# **Feature Preprocessing:**
# - LightGBM doesn't need all numeric variables and can handle categorical

# %%
model_name = "lgb"

# %%
preprocess_dict = preprocessors.preprocess_data(
    model_data,
    feature_dict=feature_dict,
    standardize=False,
    preset="pass",
)

# %%
X = preprocess_dict["X"]
y = preprocess_dict["y"]
weights = preprocess_dict["weights"]
mapping = preprocess_dict["mapping"]
md_encoded = preprocess_dict["md_encoded"]
model_features = preprocess_dict["model_features"]

X_train, X_test, y_train, y_test, weights_train, weights_test = train_test_split(
    X, y, weights, random_state=0, test_size=0.2
)

# %%
import lightgbm as lgb

if model_build:
    params = {
        "boosting_type": "gbdt",
        "objective": "regression",
        "metric": "rmse",
        "num_leaves": 31,
        "learning_rate": 0.05,
        "feature_fraction": 0.5,
        "bagging_fraction": 0.8,
        "bagging_freq": 5,
    }

    train_data = lgb.Dataset(X_train, label=y_train, weight=weights_train)
    model = lgb.train(params, train_data)
if model_load:
    model = joblib.load(f"files/models/{model_name}.joblib")
    logger.info(f"loaded model '{model_name}'. type: {type(model)}")
if model_save:
    joblib.dump(model, f"files/models/{model_name}.joblib")
    logger.info(f"saved model '{model_name}'. type: {type(model)}")

model_params = {"weights": True}
model_params.update(model.params)

# %%
predictions = model.predict(X)

# %%
model_data = calc_qx_exp_ae(model_data, predictions, model_name)

# %%
importance = get_importance(
    features=X.columns, values=model.feature_importance(importance_type="gain")
)

# %%
# get results
scorecard = model_results.get_scorecard(
    y_true_train=y_train,
    y_pred_train=model.predict(X_train),
    weights_train=weights_train,
    y_true_test=y_test,
    y_pred_test=model.predict(X_test),
    weights_test=weights_test,
    model=None,
)
model_results.add_model(
    model_name=model_name,
    data_path=pl_parquet_path,
    data_shape=model_data.shape,
    preprocess_dict=preprocess_dict,
    model_params=model_params,
    scorecard=scorecard,
    importance=importance,
)

# %%
charters.chart(
    df=importance, x_axis="feature", y_axis="importance", type="bar", y_sort=True
)

# %%
charters.compare_rates(
    model_data[model_data["insurance_plan"].isin(["UL"])],
    x_axis="insurance_plan",
    rates=["qx_raw", "qx_lgb", "qx_vbt15"],
    weights=["amount_exposed"],
    secondary="death_count",
)

# %%
charters.target(
    df=model_data,
    target="ratio",
    cols=3,
    features=model_features,
    numerator=["death_claim_amount"],
    denominator=["exp_amt_lgb"],
).show()

# %%
# lgb.plot_tree(model, tree_index=0, figsize=(20, 10))
# plt.show()

# %% [markdown]
# # Test

# %%
charters.compare_rates(
    df=model_data,
    x_axis="attained_age",
    rates=["qx_vbt15", "qx_glm"],
    weights=["amount_exposed"],
    secondary="death_count",
    display=True,
)

# %%
import plotly.io as pio

print(pio.renderers.default)
# Out:
# plotly_mimetype+notebook

# %%
import plotly.graph_objects as go
import plotly.io as pio

# pio.renderers.default = "jpeg"
# notebook_connected
# jupyterlab

fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.show()
