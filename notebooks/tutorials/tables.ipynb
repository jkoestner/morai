# %% [markdown]
# # Tables

# %% [markdown]
# Tables is a module to allow processing a number of sources of tables
#   - SOA Table
#   - File Table
#   - Rate Mapping File

# %%
import os
import sys

import pandas as pd

os.chdir("../../")
sys.path.insert(0, os.getcwd())

# %%
from morai.experience import tables
from morai.utils import custom_logger, helpers

# %% [markdown]
# ## SOA Table

# %%
mt = tables.MortTable()
tbl = mt.build_table_soa(table_list=[997])
# Out:
#  2025-09-08 23:44:17 | morai.experience.tables | INFO     | Created table that has the following dims: {'issue_age': range(0, 122), 'duration': range(1, 123)}
#  2025-09-08 23:44:17 | morai.experience.tables | INFO     | Table has 7503 cells.
#  2025-09-08 23:44:17 | morai.experience.tables | INFO     | tables: [997]

# %%
tbl
# Out:
#       issue_age  duration     vals  attained_age
# 0             0         1  0.00031             0
# 1             0         2  0.00026             1
# 2             0         3  0.00022             2
# 3             0         4  0.00017             3
# 4             0         5  0.00013             4
# ...         ...       ...      ...           ...
# 7498        119         2  0.45000           120
# 7499        119         3      NaN           121
# 7500        120         1  0.45000           120
# 7501        120         2      NaN           121
# 7502        121         1      NaN           121
#
# [7503 rows x 4 columns]

# %%
tbl2 = mt.get_soa_xml(997)

# %%
tbl2.ContentClassification.TableDescription
# Out:
# '2008 Value Basic Table (VBT) Primary Table - Female, Non-Smoker, Age Nearest Birthday. Minimum Age: 0. Maximum Age: 90'

# %%
tbl2.ContentClassification.TableName
# Out:
# '2008 VBT-Primary Female Non-Smoker ANB'

# %%
extra_dims = {"sex": ["F", "M"], "smoker_status": ["NS", "S"]}
table_list = [3224, 3234, 3252, 3262]
juv_list = [3273, 3273, 3274, 3274]
mort_table = mt.build_table_soa(
    table_list=table_list, extra_dims=extra_dims, juv_list=juv_list, extend=True, add_year=2015
)
# Out:
#  2025-07-09 00:32:07 | morai.experience.tables | INFO     | Created table that has the following dims: {'issue_age': range(0, 122), 'duration': range(1, 123), 'sex': ['F', 'M'], 'smoker_status': ['NS', 'S'], 'year': [2015]}
#  2025-07-09 00:32:07 | morai.experience.tables | INFO     | Table has 30012 cells.
#  2025-07-09 00:32:07 | morai.experience.tables | INFO     | tables: [3224, 3234, 3252, 3262]
#  2025-07-09 00:32:07 | morai.experience.tables | INFO     | juveniles: [3273, 3273, 3274, 3274]
#  2025-07-09 00:32:07 | morai.experience.tables | INFO     | extend: True, filled in 488 missing values.

# %% [markdown]
# ## File Table

# %%
file_location = helpers.FILES_PATH / "rates" / "glm.xlsx"

# %%
mt = tables.MortTable()
rate_table, mult_table = mt.build_table_workbook(
    file_location=file_location, has_mults=True
)

# %%
mult_table.head()
# Out:
#       category              subcategory  multiple
# 0  binned_face           01: 0 - 24,999  1.000000
# 1  binned_face      02: 25,000 - 99,999  0.955947
# 2  binned_face    03: 100,000 - 249,999  0.929924
# 3  binned_face  04: 250,000 - 4,999,999  0.915018
# 4  binned_face           05: 5,000,000+  0.889072

# %% [markdown]
# ## Derived Rate

# %%
rate_filename = helpers.FILES_PATH / "rates" / "rate_map.yaml"

# %%
mt = tables.MortTable(rate="glm_mults", rate_filename=rate_filename)
# Out:
#  2025-04-27 22:39:18 | morai.experience.tables | INFO     | loading 'glm_mults' from mapping file: C:\Users\johnk\Desktop\github\morai\files\rates\rate_map.yaml
#  2025-04-27 22:39:18 | morai.experience.tables | INFO     | building table for rate: 'glm_mults' with format: 'workbook'

# %%
derived_table = mt.calc_derived_table_from_mults(
    selected_dict={
        "binned_face": ["01: 0 - 24,999"],
        "class_enh": ["2_1", "3_2"],
        "insurance_plan": ["test"],
        "observation_year": [2012],
    }
)
# Out:
#  2025-04-27 22:39:44 | morai.experience.tables | INFO     | derived table using multiplier: `0.97`
#  2025-04-27 22:39:44 | morai.experience.tables | INFO     | used the following subcategories: `[['01: 0 - 24,999'], ['2_1', '3_2'], ['test'], [2012]]`

# %% [markdown]
# # Reload

# %%
import importlib

# %%
importlib.reload(tables)

# %% [markdown]
# ## Test
